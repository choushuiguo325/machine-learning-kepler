# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# install joblib to save model. 
# !pip install joblib

# %%
import pandas as pd
import tensorflow
import numpy as np

# %%
df = pd.read_csv("../Resources/cleaned_data.csv")
df
# Out:
#      koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0          CONFIRMED              0              0              0
# 1     FALSE POSITIVE              0              1              0
# 2     FALSE POSITIVE              0              1              0
# 3          CONFIRMED              0              0              0
# 4          CONFIRMED              0              0              0
# ...              ...            ...            ...            ...
# 6986  FALSE POSITIVE              0              0              0
# 6987  FALSE POSITIVE              0              1              1
# 6988       CANDIDATE              0              0              0
# 6989  FALSE POSITIVE              0              0              1
# 6990  FALSE POSITIVE              0              0              1
#
#       koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  \
# 0                 0   54.418383     2.479000e-04    -2.479000e-04
# 1                 0   19.899140     1.490000e-05    -1.490000e-05
# 2                 0    1.736952     2.630000e-07    -2.630000e-07
# 3                 0    2.525592     3.760000e-06    -3.760000e-06
# 4                 0    4.134435     1.050000e-05    -1.050000e-05
# ...             ...         ...              ...              ...
# 6986              1    8.589871     1.846000e-04    -1.846000e-04
# 6987              0    0.527699     1.160000e-07    -1.160000e-07
# 6988              0    1.739849     1.780000e-05    -1.780000e-05
# 6989              0    0.681402     2.430000e-06    -2.430000e-06
# 6990              1    4.856035     6.360000e-05    -6.360000e-05
#
#       koi_time0bk  koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  \
# 0      162.513840          0.003520  ...             -81      4.467
# 1      175.850252          0.000581  ...            -176      4.544
# 2      170.307565          0.000115  ...            -174      4.564
# 3      171.595550          0.001130  ...            -211      4.438
# 4      172.979370          0.001900  ...            -232      4.486
# ...           ...               ...  ...             ...        ...
# 6986   132.016100          0.015700  ...            -152      4.296
# 6987   131.705093          0.000170  ...            -166      4.529
# 6988   133.001270          0.007690  ...            -220      4.444
# 6989   132.181750          0.002850  ...            -236      4.447
# 6990   135.993300          0.010800  ...            -225      4.385
#
#       koi_slogg_err1  koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2  \
# 0              0.064          -0.096     0.927          0.105         -0.061
# 1              0.044          -0.176     0.868          0.233         -0.078
# 2              0.053          -0.168     0.791          0.201         -0.067
# 3              0.070          -0.210     1.046          0.334         -0.133
# 4              0.054          -0.229     0.972          0.315         -0.105
# ...              ...             ...       ...            ...            ...
# 6986           0.231          -0.189     1.088          0.313         -0.228
# 6987           0.035          -0.196     0.903          0.237         -0.079
# 6988           0.056          -0.224     1.031          0.341         -0.114
# 6989           0.056          -0.224     1.041          0.341         -0.114
# 6990           0.054          -0.216     1.193          0.410         -0.137
#
#              ra        dec  koi_kepmag
# 0     291.93423  48.141651      15.347
# 1     297.00482  48.134129      15.436
# 2     285.53461  48.285210      15.597
# 3     288.75488  48.226200      15.509
# 4     296.28613  48.224670      15.714
# ...         ...        ...         ...
# 6986  298.74921  46.973351      14.478
# 6987  297.18875  47.093819      14.082
# 6988  286.50937  47.163219      14.757
# 6989  294.16489  47.176281      15.385
# 6990  297.00977  47.121021      14.826
#
# [6991 rows x 41 columns]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
from sklearn.model_selection import train_test_split
y = df['koi_disposition']
X = df.drop(columns='koi_disposition')

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1, stratify = y)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 4002              0              0              1              0   99.673478
# 4246              0              1              0              0    0.592244
# 548               0              1              1              0    9.991625
# 3953              0              1              0              0  178.412990
# 2362              0              0              0              0   45.294223
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 4002     3.463000e-04    -3.463000e-04   219.334830          0.002300
# 4246     9.000000e-08    -9.000000e-08   131.654831          0.000124
# 548      5.360000e-06    -5.360000e-06   137.447816          0.000445
# 3953     3.100000e-05    -3.100000e-05   218.225235          0.000127
# 2362     5.600000e-05    -5.600000e-05   138.678725          0.000987
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 4002         -0.002300  ...            -148      4.777           0.040
# 4246         -0.000124  ...            -146      4.664           0.056
# 548          -0.000445  ...            -176      4.338           0.153
# 3953         -0.000127  ...            -134      4.346           0.084
# 2362         -0.000987  ...             -68      4.347           0.030
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 4002          -0.027     0.492          0.026         -0.027  293.05801
# 4246          -0.032     0.591          0.045         -0.045  290.28094
# 548           -0.187     1.096          0.309         -0.206  301.04239
# 3953          -0.126     1.148          0.202         -0.124  288.32785
# 2362          -0.030     1.044          0.057         -0.042  285.67938
#
#             dec  koi_kepmag
# 4002  45.248821      15.801
# 4246  45.464260      15.653
# 548   45.022888      14.039
# 3953  38.627621      13.944
# 2362  50.241299      10.961
#
# [5 rows x 40 columns]

# %% [markdown]
# # Pre-processing
#
# ### 1. Scale the data using the MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler
X_scaler = MinMaxScaler().fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ### 2. Standardize the data using StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

X_train_stand = X_train.copy()
X_test_stand = X_test.copy()

# only numerical features
num_cols = X.columns

# apply standardization on numerical features
for i in num_cols:
    scale = StandardScaler().fit(X_train_stand[[i]])
    X_train_stand[i] = scale.transform(X_train_stand[[i]])
    X_test_stand[i] = scale.transform(X_test_stand[[i]])

# %%
# store the trainng/test data
# %store X_train
# %store X_test
# %store y_train
# %store y_test
# %store X_train_scaled
# %store X_test_scaled 
# %store X_train_stand
# %store X_test_stand
# Out:
# Stored 'X_train' (DataFrame)
# Stored 'X_test' (DataFrame)
# Stored 'y_train' (Series)
# Stored 'y_test' (Series)
# Stored 'X_train_scaled' (ndarray)
# Stored 'X_test_scaled' (ndarray)
# Stored 'X_train_stand' (DataFrame)
# Stored 'X_test_stand' (DataFrame)

# %% [markdown]
# # Train the Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
model = LogisticRegression(max_iter = 1000)

# %%
model.fit(X_train, y_train)
print(f"The cross-validated accuracy for unprocessed training set:\n{round(cross_val_score(model,X_train, y_train,scoring='accuracy', cv=5).mean(),2)}")
# failed to converge without data's being scaled or standardized: accuracy: 66%
# Out:
# /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# The cross-validated accuracy for unprocessed training set:
# 0.66
# /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
print(f"The cross-validated accuracy for normalized training set: \n{round(cross_val_score(model,X_train_scaled, y_train,scoring='accuracy', cv=5).mean()*100,2)}%")
print(f"The cross-validated accuracy for standardized training set:\n{round(cross_val_score(model,X_train_stand, y_train,scoring='accuracy', cv=5).mean()*100,2)}%")
# Out:
# The cross-validated accuracy for normalized training set:
# 84.51%
# The cross-validated accuracy for standardized training set:
# 88.86%

# %% [markdown]
# Standardization produces higher cross-validated accuracy than normalization, so standardized data will be used for hyperparameter tuning.

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
from sklearn.metrics import classification_report

param_grid = {'C': [0.00001, 0.0001,0.001,0.01,0.1, 1, 10, 100, 1000], 
              'max_iter': [1000, 5000, 10000],
              'penalty': ["l1", "l2"],
              'solver': ['liblinear', 'lbfgs']}

# Because the "liblinear" solver does not improve the model performance and also makes the search much slower compared to "lbfgs" solver
# grid search about solver and penalty is deleted (lbfgs solver only deal with l2 penalty) for the gridsearch on standardized data
param_grid2 = {'C': [0.00001, 0.0001,0.001,0.01,0.1, 1, 10, 100, 1000], 
              'max_iter': [1000, 5000, 10000]}
model = LogisticRegression()

# %% [markdown]
# ### 1. Normalized data

# %%
grid1 = GridSearchCV(model, param_grid, verbose = 3, n_jobs = -1)
grid1.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [CV] C=1e-05, max_iter=1000, penalty=l1, solver=liblinear ............
# [CV]  C=1e-05, max_iter=1000, penalty=l1, solver=liblinear, score=0.241, total=   0.0s
# [CV] C=1e-05, max_iter=1000, penalty=l1, solver=liblinear ............
# [CV]  C=1e-05, max_iter=1000, penalty=l1, solver=liblinear, score=0.241, total=   0.0s
# [CV] C=1e-05, max_iter=1000, penalty=l1, solver=liblinear ............
# [CV]  C=1e-05, max_iter=1000, penalty=l1, solver=liblinear, score=0.241, total=   0.0s
# [CV] C=1e-05, max_iter=1000, penalty=l1, solver=liblinear ............
# [CV]  C=1e-05, max_iter=1000, penalty=l1, solver=liblinear, score=0.241, total=   0.0s
# [CV] C=1e-05, max_iter=1000, penalty=l1, solver=liblinear ............
# [CV]  C=1e-05, max_iter=1000, penalty=l1, solver=liblinear, score=0.241, total=   0.0s
# [CV] C=1e-05, max_iter=1000, penalty=l1, solver=lbfgs ................
# [CV]  C=1e-05, max_iter=1000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1e-05, max_iter=1000, penalty=l1, solver=lbfgs ................
# [CV]  C=1e-05, max_iter=1000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1e-05, max_iter=1000, penalty=l1, solver=lbfgs ................
# [CV]  C=1e-05, max_iter=1000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1e-05, max_iter=1000, penalty=l1, solver=lbfgs ................
# [CV]  C=1e-05, max_iter=1000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1e-05, max_iter=1000, penalty=l1, solver=lbfgs ................
# [CV]  C=1e-05, max_iter=1000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1e-05, max_iter=1000, penalty=l2, solver=liblinear ............
# [CV]  C=1e-05, max_iter=1000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=1e-05, max_iter=1000, penalty=l2, solver=liblinear ............
# [CV]  C=1e-05, max_iter=1000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=1e-05, max_iter=1000, penalty=l2, solver=liblinear ............
# [CV]  C=1e-05, max_iter=1000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=1e-05, max_iter=1000, penalty=l2, solver=liblinear ............
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1304, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 442, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV]  C=1e-05, max_iter=1000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=1e-05, max_iter=1000, penalty=l2, solver=liblinear ............
# [CV]  C=1e-05, max_iter=1000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=1e-05, max_iter=1000, penalty=l2, solver=lbfgs ................
# [CV]  C=1e-05, max_iter=1000, penalty=l2, solver=lbfgs, score=0.501, total=   0.0s
# [CV] C=1e-05, max_iter=1000, penalty=l2, solver=lbfgs ................
# [CV]  C=1e-05, max_iter=1000, penalty=l2, solver=lbfgs, score=0.501, total=   0.0s
# [CV] C=1e-05, max_iter=1000, penalty=l2, solver=lbfgs ................
# [CV]  C=1e-05, max_iter=1000, penalty=l2, solver=lbfgs, score=0.501, total=   0.0s
# [CV] C=1e-05, max_iter=1000, penalty=l2, solver=lbfgs ................
# [CV]  C=1e-05, max_iter=1000, penalty=l2, solver=lbfgs, score=0.501, total=   0.0s
# [CV] C=1e-05, max_iter=1000, penalty=l2, solver=lbfgs ................
# [CV]  C=1e-05, max_iter=1000, penalty=l2, solver=lbfgs, score=0.501, total=   0.0s
# [CV] C=1e-05, max_iter=5000, penalty=l1, solver=liblinear ............
# [CV]  C=1e-05, max_iter=5000, penalty=l1, solver=liblinear, score=0.241, total=   0.0s
# [CV] C=1e-05, max_iter=5000, penalty=l1, solver=liblinear ............
# [CV]  C=1e-05, max_iter=5000, penalty=l1, solver=liblinear, score=0.241, total=   0.0s
# [CV] C=1e-05, max_iter=5000, penalty=l1, solver=liblinear ............
# [CV]  C=1e-05, max_iter=5000, penalty=l1, solver=liblinear, score=0.241, total=   0.0s
# [CV] C=1e-05, max_iter=5000, penalty=l1, solver=liblinear ............
# [CV]  C=1e-05, max_iter=5000, penalty=l1, solver=liblinear, score=0.241, total=   0.0s
# [CV] C=1e-05, max_iter=5000, penalty=l1, solver=liblinear ............
# [CV]  C=1e-05, max_iter=5000, penalty=l1, solver=liblinear, score=0.241, total=   0.0s
# [CV] C=1e-05, max_iter=5000, penalty=l1, solver=lbfgs ................
# [CV]  C=1e-05, max_iter=5000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1e-05, max_iter=5000, penalty=l1, solver=lbfgs ................
# [CV]  C=1e-05, max_iter=5000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1e-05, max_iter=5000, penalty=l1, solver=lbfgs ................
# [CV]  C=1e-05, max_iter=5000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1e-05, max_iter=5000, penalty=l1, solver=lbfgs ................
# [CV]  C=1e-05, max_iter=5000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1e-05, max_iter=5000, penalty=l1, solver=lbfgs ................
# [CV]  C=1e-05, max_iter=5000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1e-05, max_iter=5000, penalty=l2, solver=liblinear ............
# [CV]  C=1e-05, max_iter=5000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=1e-05, max_iter=5000, penalty=l2, solver=liblinear ............
# [CV]  C=1e-05, max_iter=5000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=1e-05, max_iter=5000, penalty=l2, solver=liblinear ............
# [CV]  C=1e-05, max_iter=5000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=1e-05, max_iter=5000, penalty=l2, solver=liblinear ............
# [CV]  C=1e-05, max_iter=5000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=1e-05, max_iter=5000, penalty=l2, solver=liblinear ............
# [CV]  C=1e-05, max_iter=5000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=1e-05, max_iter=5000, penalty=l2, solver=lbfgs ................
# [CV]  C=1e-05, max_iter=5000, penalty=l2, solver=lbfgs, score=0.501, total=   0.0s
# [CV] C=1e-05, max_iter=5000, penalty=l2, solver=lbfgs ................
# /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1304, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 442, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV]  C=1e-05, max_iter=5000, penalty=l2, solver=lbfgs, score=0.501, total=   0.0s
# [CV] C=1e-05, max_iter=5000, penalty=l2, solver=lbfgs ................
# [CV]  C=1e-05, max_iter=5000, penalty=l2, solver=lbfgs, score=0.501, total=   0.0s
# [CV] C=1e-05, max_iter=5000, penalty=l2, solver=lbfgs ................
# [CV]  C=1e-05, max_iter=5000, penalty=l2, solver=lbfgs, score=0.501, total=   0.0s
# [CV] C=1e-05, max_iter=5000, penalty=l2, solver=lbfgs ................
# [CV]  C=1e-05, max_iter=5000, penalty=l2, solver=lbfgs, score=0.501, total=   0.0s
# [CV] C=1e-05, max_iter=10000, penalty=l1, solver=liblinear ...........
# [CV]  C=1e-05, max_iter=10000, penalty=l1, solver=liblinear, score=0.241, total=   0.0s
# [CV] C=1e-05, max_iter=10000, penalty=l1, solver=liblinear ...........
# [CV]  C=1e-05, max_iter=10000, penalty=l1, solver=liblinear, score=0.241, total=   0.0s
# [CV] C=1e-05, max_iter=10000, penalty=l1, solver=liblinear ...........
# [CV]  C=1e-05, max_iter=10000, penalty=l1, solver=liblinear, score=0.241, total=   0.0s
# [CV] C=1e-05, max_iter=10000, penalty=l1, solver=liblinear ...........
# [CV]  C=1e-05, max_iter=10000, penalty=l1, solver=liblinear, score=0.241, total=   0.0s
# [CV] C=1e-05, max_iter=10000, penalty=l1, solver=liblinear ...........
# [CV]  C=1e-05, max_iter=10000, penalty=l1, solver=liblinear, score=0.241, total=   0.0s
# [CV] C=1e-05, max_iter=10000, penalty=l1, solver=lbfgs ...............
# [CV]  C=1e-05, max_iter=10000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1e-05, max_iter=10000, penalty=l1, solver=lbfgs ...............
# [CV]  C=1e-05, max_iter=10000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1e-05, max_iter=10000, penalty=l1, solver=lbfgs ...............
# [CV]  C=1e-05, max_iter=10000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1e-05, max_iter=10000, penalty=l1, solver=lbfgs ...............
# [CV]  C=1e-05, max_iter=10000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1e-05, max_iter=10000, penalty=l1, solver=lbfgs ...............
# [CV]  C=1e-05, max_iter=10000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1e-05, max_iter=10000, penalty=l2, solver=liblinear ...........
# /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1304, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 442, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV]  C=1e-05, max_iter=10000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=1e-05, max_iter=10000, penalty=l2, solver=liblinear ...........
# [CV]  C=1e-05, max_iter=10000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=1e-05, max_iter=10000, penalty=l2, solver=liblinear ...........
# [CV]  C=1e-05, max_iter=10000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=1e-05, max_iter=10000, penalty=l2, solver=liblinear ...........
# [CV]  C=1e-05, max_iter=10000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=1e-05, max_iter=10000, penalty=l2, solver=liblinear ...........
# [CV]  C=1e-05, max_iter=10000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=1e-05, max_iter=10000, penalty=l2, solver=lbfgs ...............
# [CV]  C=1e-05, max_iter=10000, penalty=l2, solver=lbfgs, score=0.501, total=   0.0s
# [CV] C=1e-05, max_iter=10000, penalty=l2, solver=lbfgs ...............
# [CV]  C=1e-05, max_iter=10000, penalty=l2, solver=lbfgs, score=0.501, total=   0.0s
# [CV] C=1e-05, max_iter=10000, penalty=l2, solver=lbfgs ...............
# [CV]  C=1e-05, max_iter=10000, penalty=l2, solver=lbfgs, score=0.501, total=   0.0s
# [CV] C=1e-05, max_iter=10000, penalty=l2, solver=lbfgs ...............
# [CV]  C=1e-05, max_iter=10000, penalty=l2, solver=lbfgs, score=0.501, total=   0.1s
# [CV] C=1e-05, max_iter=10000, penalty=l2, solver=lbfgs ...............
# [CV]  C=1e-05, max_iter=10000, penalty=l2, solver=lbfgs, score=0.501, total=   0.0s
# [CV] C=0.0001, max_iter=1000, penalty=l1, solver=liblinear ...........
# [CV]  C=0.0001, max_iter=1000, penalty=l1, solver=liblinear, score=0.241, total=   0.0s
# [CV] C=0.0001, max_iter=1000, penalty=l1, solver=liblinear ...........
# [CV]  C=0.0001, max_iter=1000, penalty=l1, solver=liblinear, score=0.241, total=   0.0s
# [CV] C=0.0001, max_iter=1000, penalty=l1, solver=liblinear ...........
# [CV]  C=0.0001, max_iter=1000, penalty=l1, solver=liblinear, score=0.241, total=   0.0s
# [CV] C=0.0001, max_iter=1000, penalty=l1, solver=liblinear ...........
# [CV]  C=0.0001, max_iter=1000, penalty=l1, solver=liblinear, score=0.241, total=   0.0s
# [CV] C=0.0001, max_iter=1000, penalty=l1, solver=liblinear ...........
# [CV]  C=0.0001, max_iter=1000, penalty=l1, solver=liblinear, score=0.241, total=   0.0s
# [CV] C=0.0001, max_iter=1000, penalty=l1, solver=lbfgs ...............
# [CV]  C=0.0001, max_iter=1000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.0001, max_iter=1000, penalty=l1, solver=lbfgs ...............
# [CV]  C=0.0001, max_iter=1000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.0001, max_iter=1000, penalty=l1, solver=lbfgs ...............
# [CV]  C=0.0001, max_iter=1000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.0001, max_iter=1000, penalty=l1, solver=lbfgs ...............
# [CV]  C=0.0001, max_iter=1000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.0001, max_iter=1000, penalty=l1, solver=lbfgs ...............
# [CV]  C=0.0001, max_iter=1000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.0001, max_iter=1000, penalty=l2, solver=liblinear ...........
# [CV]  C=0.0001, max_iter=1000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.0001, max_iter=1000, penalty=l2, solver=liblinear ...........
# [CV]  C=0.0001, max_iter=1000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.0001, max_iter=1000, penalty=l2, solver=liblinear ...........
# /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1304, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 442, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV]  C=0.0001, max_iter=1000, penalty=l2, solver=liblinear, score=0.501, total=   0.1s
# [CV] C=0.0001, max_iter=1000, penalty=l2, solver=liblinear ...........
# [CV]  C=0.0001, max_iter=1000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.0001, max_iter=1000, penalty=l2, solver=liblinear ...........
# [CV]  C=0.0001, max_iter=1000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.0001, max_iter=1000, penalty=l2, solver=lbfgs ...............
# [CV]  C=0.0001, max_iter=1000, penalty=l2, solver=lbfgs, score=0.501, total=   0.1s
# [CV] C=0.0001, max_iter=1000, penalty=l2, solver=lbfgs ...............
# [CV]  C=0.0001, max_iter=1000, penalty=l2, solver=lbfgs, score=0.501, total=   0.1s
# [CV] C=0.0001, max_iter=1000, penalty=l2, solver=lbfgs ...............
# [CV]  C=0.0001, max_iter=1000, penalty=l2, solver=lbfgs, score=0.501, total=   0.0s
# [CV] C=0.0001, max_iter=1000, penalty=l2, solver=lbfgs ...............
# [CV]  C=0.0001, max_iter=1000, penalty=l2, solver=lbfgs, score=0.501, total=   0.0s
# [CV] C=0.0001, max_iter=1000, penalty=l2, solver=lbfgs ...............
# [CV]  C=0.0001, max_iter=1000, penalty=l2, solver=lbfgs, score=0.501, total=   0.0s
# [CV] C=0.0001, max_iter=5000, penalty=l1, solver=liblinear ...........
# [CV]  C=0.0001, max_iter=5000, penalty=l1, solver=liblinear, score=0.241, total=   0.0s
# [CV] C=0.0001, max_iter=5000, penalty=l1, solver=liblinear ...........
# [CV]  C=0.0001, max_iter=5000, penalty=l1, solver=liblinear, score=0.241, total=   0.0s
# [CV] C=0.0001, max_iter=5000, penalty=l1, solver=liblinear ...........
# [CV]  C=0.0001, max_iter=5000, penalty=l1, solver=liblinear, score=0.241, total=   0.0s
# [CV] C=0.0001, max_iter=5000, penalty=l1, solver=liblinear ...........
# [CV]  C=0.0001, max_iter=5000, penalty=l1, solver=liblinear, score=0.241, total=   0.0s
# [CV] C=0.0001, max_iter=5000, penalty=l1, solver=liblinear ...........
# [CV]  C=0.0001, max_iter=5000, penalty=l1, solver=liblinear, score=0.241, total=   0.0s
# [CV] C=0.0001, max_iter=5000, penalty=l1, solver=lbfgs ...............
# [CV]  C=0.0001, max_iter=5000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.0001, max_iter=5000, penalty=l1, solver=lbfgs ...............
# [CV]  C=0.0001, max_iter=5000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.0001, max_iter=5000, penalty=l1, solver=lbfgs ...............
# [CV]  C=0.0001, max_iter=5000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.0001, max_iter=5000, penalty=l1, solver=lbfgs ...............
# [CV]  C=0.0001, max_iter=5000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.0001, max_iter=5000, penalty=l1, solver=lbfgs ...............
# [CV]  C=0.0001, max_iter=5000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.0001, max_iter=5000, penalty=l2, solver=liblinear ...........
# [CV]  C=0.0001, max_iter=5000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.0001, max_iter=5000, penalty=l2, solver=liblinear ...........
# [CV]  C=0.0001, max_iter=5000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.0001, max_iter=5000, penalty=l2, solver=liblinear ...........
# [CV]  C=0.0001, max_iter=5000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.0001, max_iter=5000, penalty=l2, solver=liblinear ...........
# [CV]  C=0.0001, max_iter=5000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.0001, max_iter=5000, penalty=l2, solver=liblinear ...........
# [CV]  C=0.0001, max_iter=5000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.0001, max_iter=5000, penalty=l2, solver=lbfgs ...............
# [CV]  C=0.0001, max_iter=5000, penalty=l2, solver=lbfgs, score=0.501, total=   0.0s
# [CV] C=0.0001, max_iter=5000, penalty=l2, solver=lbfgs ...............
# /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1304, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 442, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV]  C=0.0001, max_iter=5000, penalty=l2, solver=lbfgs, score=0.501, total=   0.0s
# [CV] C=0.0001, max_iter=5000, penalty=l2, solver=lbfgs ...............
# [CV]  C=0.0001, max_iter=5000, penalty=l2, solver=lbfgs, score=0.501, total=   0.0s
# [CV] C=0.0001, max_iter=5000, penalty=l2, solver=lbfgs ...............
# [CV]  C=0.0001, max_iter=5000, penalty=l2, solver=lbfgs, score=0.501, total=   0.1s
# [CV] C=0.0001, max_iter=5000, penalty=l2, solver=lbfgs ...............
# [CV]  C=0.0001, max_iter=5000, penalty=l2, solver=lbfgs, score=0.501, total=   0.1s
# [CV] C=0.0001, max_iter=10000, penalty=l1, solver=liblinear ..........
# [CV]  C=0.0001, max_iter=10000, penalty=l1, solver=liblinear, score=0.241, total=   0.0s
# [CV] C=0.0001, max_iter=10000, penalty=l1, solver=liblinear ..........
# [CV]  C=0.0001, max_iter=10000, penalty=l1, solver=liblinear, score=0.241, total=   0.0s
# [CV] C=0.0001, max_iter=10000, penalty=l1, solver=liblinear ..........
# [CV]  C=0.0001, max_iter=10000, penalty=l1, solver=liblinear, score=0.241, total=   0.0s
# [CV] C=0.0001, max_iter=10000, penalty=l1, solver=liblinear ..........
# [CV]  C=0.0001, max_iter=10000, penalty=l1, solver=liblinear, score=0.241, total=   0.0s
# [CV] C=0.0001, max_iter=10000, penalty=l1, solver=liblinear ..........
# [CV]  C=0.0001, max_iter=10000, penalty=l1, solver=liblinear, score=0.241, total=   0.0s
# [CV] C=0.0001, max_iter=10000, penalty=l1, solver=lbfgs ..............
# [CV]  C=0.0001, max_iter=10000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.0001, max_iter=10000, penalty=l1, solver=lbfgs ..............
# [CV]  C=0.0001, max_iter=10000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.0001, max_iter=10000, penalty=l1, solver=lbfgs ..............
# [CV]  C=0.0001, max_iter=10000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.0001, max_iter=10000, penalty=l1, solver=lbfgs ..............
# [CV]  C=0.0001, max_iter=10000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.0001, max_iter=10000, penalty=l1, solver=lbfgs ..............
# [CV]  C=0.0001, max_iter=10000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.0001, max_iter=10000, penalty=l2, solver=liblinear ..........
# [CV]  C=0.0001, max_iter=10000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.0001, max_iter=10000, penalty=l2, solver=liblinear ..........
# [CV]  C=0.0001, max_iter=10000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.0001, max_iter=10000, penalty=l2, solver=liblinear ..........
# [CV]  C=0.0001, max_iter=10000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.0001, max_iter=10000, penalty=l2, solver=liblinear ..........
# /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1304, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 442, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV]  C=0.0001, max_iter=10000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.0001, max_iter=10000, penalty=l2, solver=liblinear ..........
# [CV]  C=0.0001, max_iter=10000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.0001, max_iter=10000, penalty=l2, solver=lbfgs ..............
# [CV]  C=0.0001, max_iter=10000, penalty=l2, solver=lbfgs, score=0.501, total=   0.0s
# [CV] C=0.0001, max_iter=10000, penalty=l2, solver=lbfgs ..............
# [CV]  C=0.0001, max_iter=10000, penalty=l2, solver=lbfgs, score=0.501, total=   0.0s
# [CV] C=0.0001, max_iter=10000, penalty=l2, solver=lbfgs ..............
# [CV]  C=0.0001, max_iter=10000, penalty=l2, solver=lbfgs, score=0.501, total=   0.0s
# [CV] C=0.0001, max_iter=10000, penalty=l2, solver=lbfgs ..............
# [CV]  C=0.0001, max_iter=10000, penalty=l2, solver=lbfgs, score=0.501, total=   0.0s
# [CV] C=0.0001, max_iter=10000, penalty=l2, solver=lbfgs ..............
# [CV]  C=0.0001, max_iter=10000, penalty=l2, solver=lbfgs, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=1000, penalty=l1, solver=liblinear ............
# [CV]  C=0.001, max_iter=1000, penalty=l1, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=1000, penalty=l1, solver=liblinear ............
# [CV]  C=0.001, max_iter=1000, penalty=l1, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=1000, penalty=l1, solver=liblinear ............
# [CV]  C=0.001, max_iter=1000, penalty=l1, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=1000, penalty=l1, solver=liblinear ............
# [CV]  C=0.001, max_iter=1000, penalty=l1, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=1000, penalty=l1, solver=liblinear ............
# [CV]  C=0.001, max_iter=1000, penalty=l1, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=1000, penalty=l1, solver=lbfgs ................
# [CV]  C=0.001, max_iter=1000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.001, max_iter=1000, penalty=l1, solver=lbfgs ................
# [CV]  C=0.001, max_iter=1000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.001, max_iter=1000, penalty=l1, solver=lbfgs ................
# [CV]  C=0.001, max_iter=1000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.001, max_iter=1000, penalty=l1, solver=lbfgs ................
# [CV]  C=0.001, max_iter=1000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.001, max_iter=1000, penalty=l1, solver=lbfgs ................
# [CV]  C=0.001, max_iter=1000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.001, max_iter=1000, penalty=l2, solver=liblinear ............
# [CV]  C=0.001, max_iter=1000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=1000, penalty=l2, solver=liblinear ............
# [CV]  C=0.001, max_iter=1000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=1000, penalty=l2, solver=liblinear ............
# [CV]  C=0.001, max_iter=1000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=1000, penalty=l2, solver=liblinear ............
# [CV]  C=0.001, max_iter=1000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=1000, penalty=l2, solver=liblinear ............
# /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1304, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 442, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV]  C=0.001, max_iter=1000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=1000, penalty=l2, solver=lbfgs ................
# [CV]  C=0.001, max_iter=1000, penalty=l2, solver=lbfgs, score=0.501, total=   0.1s
# [CV] C=0.001, max_iter=1000, penalty=l2, solver=lbfgs ................
# [CV]  C=0.001, max_iter=1000, penalty=l2, solver=lbfgs, score=0.501, total=   0.1s
# [CV] C=0.001, max_iter=1000, penalty=l2, solver=lbfgs ................
# [CV]  C=0.001, max_iter=1000, penalty=l2, solver=lbfgs, score=0.501, total=   0.1s
# [CV] C=0.001, max_iter=1000, penalty=l2, solver=lbfgs ................
# [CV]  C=0.001, max_iter=1000, penalty=l2, solver=lbfgs, score=0.501, total=   0.1s
# [CV] C=0.001, max_iter=1000, penalty=l2, solver=lbfgs ................
# [CV]  C=0.001, max_iter=1000, penalty=l2, solver=lbfgs, score=0.501, total=   0.1s
# [CV] C=0.001, max_iter=5000, penalty=l1, solver=liblinear ............
# [CV]  C=0.001, max_iter=5000, penalty=l1, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=5000, penalty=l1, solver=liblinear ............
# [CV]  C=0.001, max_iter=5000, penalty=l1, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=5000, penalty=l1, solver=liblinear ............
# [CV]  C=0.001, max_iter=5000, penalty=l1, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=5000, penalty=l1, solver=liblinear ............
# [CV]  C=0.001, max_iter=5000, penalty=l1, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=5000, penalty=l1, solver=liblinear ............
# [CV]  C=0.001, max_iter=5000, penalty=l1, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=5000, penalty=l1, solver=lbfgs ................
# [CV]  C=0.001, max_iter=5000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.001, max_iter=5000, penalty=l1, solver=lbfgs ................
# [CV]  C=0.001, max_iter=5000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.001, max_iter=5000, penalty=l1, solver=lbfgs ................
# [CV]  C=0.001, max_iter=5000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.001, max_iter=5000, penalty=l1, solver=lbfgs ................
# [CV]  C=0.001, max_iter=5000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.001, max_iter=5000, penalty=l1, solver=lbfgs ................
# [CV]  C=0.001, max_iter=5000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.001, max_iter=5000, penalty=l2, solver=liblinear ............
# [CV]  C=0.001, max_iter=5000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=5000, penalty=l2, solver=liblinear ............
# [CV]  C=0.001, max_iter=5000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=5000, penalty=l2, solver=liblinear ............
# [CV]  C=0.001, max_iter=5000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=5000, penalty=l2, solver=liblinear ............
# [CV]  C=0.001, max_iter=5000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=5000, penalty=l2, solver=liblinear ............
# [CV]  C=0.001, max_iter=5000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=5000, penalty=l2, solver=lbfgs ................
# /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1304, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 442, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV]  C=0.001, max_iter=5000, penalty=l2, solver=lbfgs, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=5000, penalty=l2, solver=lbfgs ................
# [CV]  C=0.001, max_iter=5000, penalty=l2, solver=lbfgs, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=5000, penalty=l2, solver=lbfgs ................
# [CV]  C=0.001, max_iter=5000, penalty=l2, solver=lbfgs, score=0.501, total=   0.1s
# [CV] C=0.001, max_iter=5000, penalty=l2, solver=lbfgs ................
# [CV]  C=0.001, max_iter=5000, penalty=l2, solver=lbfgs, score=0.501, total=   0.1s
# [CV] C=0.001, max_iter=5000, penalty=l2, solver=lbfgs ................
# [CV]  C=0.001, max_iter=5000, penalty=l2, solver=lbfgs, score=0.501, total=   0.1s
# [CV] C=0.001, max_iter=10000, penalty=l1, solver=liblinear ...........
# [CV]  C=0.001, max_iter=10000, penalty=l1, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=10000, penalty=l1, solver=liblinear ...........
# [CV]  C=0.001, max_iter=10000, penalty=l1, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=10000, penalty=l1, solver=liblinear ...........
# [CV]  C=0.001, max_iter=10000, penalty=l1, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=10000, penalty=l1, solver=liblinear ...........
# [CV]  C=0.001, max_iter=10000, penalty=l1, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=10000, penalty=l1, solver=liblinear ...........
# [CV]  C=0.001, max_iter=10000, penalty=l1, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=10000, penalty=l1, solver=lbfgs ...............
# [CV]  C=0.001, max_iter=10000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.001, max_iter=10000, penalty=l1, solver=lbfgs ...............
# [CV]  C=0.001, max_iter=10000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.001, max_iter=10000, penalty=l1, solver=lbfgs ...............
# [CV]  C=0.001, max_iter=10000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.001, max_iter=10000, penalty=l1, solver=lbfgs ...............
# [CV]  C=0.001, max_iter=10000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.001, max_iter=10000, penalty=l1, solver=lbfgs ...............
# [CV]  C=0.001, max_iter=10000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.001, max_iter=10000, penalty=l2, solver=liblinear ...........
# [CV]  C=0.001, max_iter=10000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=10000, penalty=l2, solver=liblinear ...........
# /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1304, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 442, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV]  C=0.001, max_iter=10000, penalty=l2, solver=liblinear, score=0.501, total=   0.1s
# [CV] C=0.001, max_iter=10000, penalty=l2, solver=liblinear ...........
# [CV]  C=0.001, max_iter=10000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=10000, penalty=l2, solver=liblinear ...........
# [CV]  C=0.001, max_iter=10000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=10000, penalty=l2, solver=liblinear ...........
# [CV]  C=0.001, max_iter=10000, penalty=l2, solver=liblinear, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=10000, penalty=l2, solver=lbfgs ...............
# [CV]  C=0.001, max_iter=10000, penalty=l2, solver=lbfgs, score=0.501, total=   0.1s
# [CV] C=0.001, max_iter=10000, penalty=l2, solver=lbfgs ...............
# [CV]  C=0.001, max_iter=10000, penalty=l2, solver=lbfgs, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=10000, penalty=l2, solver=lbfgs ...............
# [CV]  C=0.001, max_iter=10000, penalty=l2, solver=lbfgs, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=10000, penalty=l2, solver=lbfgs ...............
# [CV]  C=0.001, max_iter=10000, penalty=l2, solver=lbfgs, score=0.501, total=   0.0s
# [CV] C=0.001, max_iter=10000, penalty=l2, solver=lbfgs ...............
# [CV]  C=0.001, max_iter=10000, penalty=l2, solver=lbfgs, score=0.501, total=   0.0s
# [CV] C=0.01, max_iter=1000, penalty=l1, solver=liblinear .............
# [CV]  C=0.01, max_iter=1000, penalty=l1, solver=liblinear, score=0.747, total=   0.1s
# [CV] C=0.01, max_iter=1000, penalty=l1, solver=liblinear .............
# [CV]  C=0.01, max_iter=1000, penalty=l1, solver=liblinear, score=0.741, total=   0.1s
# [CV] C=0.01, max_iter=1000, penalty=l1, solver=liblinear .............
# [CV]  C=0.01, max_iter=1000, penalty=l1, solver=liblinear, score=0.739, total=   0.1s
# [CV] C=0.01, max_iter=1000, penalty=l1, solver=liblinear .............
# [CV]  C=0.01, max_iter=1000, penalty=l1, solver=liblinear, score=0.740, total=   0.1s
# [CV] C=0.01, max_iter=1000, penalty=l1, solver=liblinear .............
# [CV]  C=0.01, max_iter=1000, penalty=l1, solver=liblinear, score=0.739, total=   0.1s
# [CV] C=0.01, max_iter=1000, penalty=l1, solver=lbfgs .................
# [CV]  C=0.01, max_iter=1000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.01, max_iter=1000, penalty=l1, solver=lbfgs .................
# [CV]  C=0.01, max_iter=1000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.01, max_iter=1000, penalty=l1, solver=lbfgs .................
# [CV]  C=0.01, max_iter=1000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.01, max_iter=1000, penalty=l1, solver=lbfgs .................
# [CV]  C=0.01, max_iter=1000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.01, max_iter=1000, penalty=l1, solver=lbfgs .................
# [CV]  C=0.01, max_iter=1000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.01, max_iter=1000, penalty=l2, solver=liblinear .............
# [CV]  C=0.01, max_iter=1000, penalty=l2, solver=liblinear, score=0.810, total=   0.0s
# [CV] C=0.01, max_iter=1000, penalty=l2, solver=liblinear .............
# /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1304, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 442, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV]  C=0.01, max_iter=1000, penalty=l2, solver=liblinear, score=0.787, total=   0.0s
# [CV] C=0.01, max_iter=1000, penalty=l2, solver=liblinear .............
# [CV]  C=0.01, max_iter=1000, penalty=l2, solver=liblinear, score=0.786, total=   0.0s
# [CV] C=0.01, max_iter=1000, penalty=l2, solver=liblinear .............
# [CV]  C=0.01, max_iter=1000, penalty=l2, solver=liblinear, score=0.802, total=   0.0s
# [CV] C=0.01, max_iter=1000, penalty=l2, solver=liblinear .............
# [CV]  C=0.01, max_iter=1000, penalty=l2, solver=liblinear, score=0.794, total=   0.0s
# [CV] C=0.01, max_iter=1000, penalty=l2, solver=lbfgs .................
# [CV]  C=0.01, max_iter=1000, penalty=l2, solver=lbfgs, score=0.830, total=   0.1s
# [CV] C=0.01, max_iter=1000, penalty=l2, solver=lbfgs .................
# [CV]  C=0.01, max_iter=1000, penalty=l2, solver=lbfgs, score=0.810, total=   0.1s
# [CV] C=0.01, max_iter=1000, penalty=l2, solver=lbfgs .................
# [CV]  C=0.01, max_iter=1000, penalty=l2, solver=lbfgs, score=0.799, total=   0.2s
# [CV] C=0.01, max_iter=1000, penalty=l2, solver=lbfgs .................
# [CV]  C=0.01, max_iter=1000, penalty=l2, solver=lbfgs, score=0.829, total=   0.1s
# [CV] C=0.01, max_iter=1000, penalty=l2, solver=lbfgs .................
# [CV]  C=0.01, max_iter=1000, penalty=l2, solver=lbfgs, score=0.787, total=   0.1s
# [CV] C=0.01, max_iter=5000, penalty=l1, solver=liblinear .............
# [CV]  C=0.01, max_iter=5000, penalty=l1, solver=liblinear, score=0.747, total=   0.1s
# [CV] C=0.01, max_iter=5000, penalty=l1, solver=liblinear .............
# [CV]  C=0.01, max_iter=5000, penalty=l1, solver=liblinear, score=0.741, total=   0.0s
# [CV] C=0.01, max_iter=5000, penalty=l1, solver=liblinear .............
# [CV]  C=0.01, max_iter=5000, penalty=l1, solver=liblinear, score=0.739, total=   0.1s
# [CV] C=0.01, max_iter=5000, penalty=l1, solver=liblinear .............
# [CV]  C=0.01, max_iter=5000, penalty=l1, solver=liblinear, score=0.740, total=   0.1s
# [CV] C=0.01, max_iter=5000, penalty=l1, solver=liblinear .............
# [CV]  C=0.01, max_iter=5000, penalty=l1, solver=liblinear, score=0.739, total=   0.1s
# [CV] C=0.01, max_iter=5000, penalty=l1, solver=lbfgs .................
# [CV]  C=0.01, max_iter=5000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.01, max_iter=5000, penalty=l1, solver=lbfgs .................
# [CV]  C=0.01, max_iter=5000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.01, max_iter=5000, penalty=l1, solver=lbfgs .................
# [CV]  C=0.01, max_iter=5000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.01, max_iter=5000, penalty=l1, solver=lbfgs .................
# [CV]  C=0.01, max_iter=5000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.01, max_iter=5000, penalty=l1, solver=lbfgs .................
# [CV]  C=0.01, max_iter=5000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.01, max_iter=5000, penalty=l2, solver=liblinear .............
# [CV]  C=0.01, max_iter=5000, penalty=l2, solver=liblinear, score=0.810, total=   0.0s
# [CV] C=0.01, max_iter=5000, penalty=l2, solver=liblinear .............
# [CV]  C=0.01, max_iter=5000, penalty=l2, solver=liblinear, score=0.787, total=   0.0s
# [CV] C=0.01, max_iter=5000, penalty=l2, solver=liblinear .............
# /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1304, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 442, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV]  C=0.01, max_iter=5000, penalty=l2, solver=liblinear, score=0.786, total=   0.0s
# [CV] C=0.01, max_iter=5000, penalty=l2, solver=liblinear .............
# [CV]  C=0.01, max_iter=5000, penalty=l2, solver=liblinear, score=0.802, total=   0.0s
# [CV] C=0.01, max_iter=5000, penalty=l2, solver=liblinear .............
# [CV]  C=0.01, max_iter=5000, penalty=l2, solver=liblinear, score=0.794, total=   0.0s
# [CV] C=0.01, max_iter=5000, penalty=l2, solver=lbfgs .................
# [CV]  C=0.01, max_iter=5000, penalty=l2, solver=lbfgs, score=0.830, total=   0.1s
# [CV] C=0.01, max_iter=5000, penalty=l2, solver=lbfgs .................
# [CV]  C=0.01, max_iter=5000, penalty=l2, solver=lbfgs, score=0.810, total=   0.1s
# [CV] C=0.01, max_iter=5000, penalty=l2, solver=lbfgs .................
# [CV]  C=0.01, max_iter=5000, penalty=l2, solver=lbfgs, score=0.799, total=   0.1s
# [CV] C=0.01, max_iter=5000, penalty=l2, solver=lbfgs .................
# [CV]  C=0.01, max_iter=5000, penalty=l2, solver=lbfgs, score=0.829, total=   0.2s
# [CV] C=0.01, max_iter=5000, penalty=l2, solver=lbfgs .................
# [CV]  C=0.01, max_iter=5000, penalty=l2, solver=lbfgs, score=0.787, total=   0.1s
# [CV] C=0.01, max_iter=10000, penalty=l1, solver=liblinear ............
# [CV]  C=0.01, max_iter=10000, penalty=l1, solver=liblinear, score=0.747, total=   0.1s
# [CV] C=0.01, max_iter=10000, penalty=l1, solver=liblinear ............
# [CV]  C=0.01, max_iter=10000, penalty=l1, solver=liblinear, score=0.741, total=   0.1s
# [CV] C=0.01, max_iter=10000, penalty=l1, solver=liblinear ............
# [CV]  C=0.01, max_iter=10000, penalty=l1, solver=liblinear, score=0.739, total=   0.1s
# [CV] C=0.01, max_iter=10000, penalty=l1, solver=liblinear ............
# [CV]  C=0.01, max_iter=10000, penalty=l1, solver=liblinear, score=0.740, total=   0.1s
# [CV] C=0.01, max_iter=10000, penalty=l1, solver=liblinear ............
# [CV]  C=0.01, max_iter=10000, penalty=l1, solver=liblinear, score=0.739, total=   0.2s
# [CV] C=0.01, max_iter=10000, penalty=l1, solver=lbfgs ................
# [CV]  C=0.01, max_iter=10000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.01, max_iter=10000, penalty=l1, solver=lbfgs ................
# [CV]  C=0.01, max_iter=10000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.01, max_iter=10000, penalty=l1, solver=lbfgs ................
# [CV]  C=0.01, max_iter=10000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.01, max_iter=10000, penalty=l1, solver=lbfgs ................
# [CV]  C=0.01, max_iter=10000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.01, max_iter=10000, penalty=l1, solver=lbfgs ................
# [CV]  C=0.01, max_iter=10000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=0.01, max_iter=10000, penalty=l2, solver=liblinear ............
# [CV]  C=0.01, max_iter=10000, penalty=l2, solver=liblinear, score=0.810, total=   0.1s
# [CV] C=0.01, max_iter=10000, penalty=l2, solver=liblinear ............
# [CV]  C=0.01, max_iter=10000, penalty=l2, solver=liblinear, score=0.787, total=   0.1s
# [CV] C=0.01, max_iter=10000, penalty=l2, solver=liblinear ............
# /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1304, in fit
# ...
# [CV] C=100, max_iter=10000, penalty=l2, solver=lbfgs .................
# [CV]  C=100, max_iter=10000, penalty=l2, solver=lbfgs, score=0.882, total=   1.8s
# [CV] C=100, max_iter=10000, penalty=l2, solver=lbfgs .................
# [CV]  C=100, max_iter=10000, penalty=l2, solver=lbfgs, score=0.869, total=   1.7s
# [CV] C=100, max_iter=10000, penalty=l2, solver=lbfgs .................
# [CV]  C=100, max_iter=10000, penalty=l2, solver=lbfgs, score=0.887, total=   1.9s
# [CV] C=100, max_iter=10000, penalty=l2, solver=lbfgs .................
# [CV]  C=100, max_iter=10000, penalty=l2, solver=lbfgs, score=0.884, total=   1.8s
# [CV] C=1000, max_iter=1000, penalty=l1, solver=liblinear .............
# [CV]  C=1000, max_iter=1000, penalty=l1, solver=liblinear, score=0.898, total=  18.0s
# [CV] C=1000, max_iter=1000, penalty=l1, solver=liblinear .............
# [CV]  C=1000, max_iter=1000, penalty=l1, solver=liblinear, score=0.876, total=  11.0s
# [CV] C=1000, max_iter=1000, penalty=l1, solver=liblinear .............
# [CV]  C=1000, max_iter=1000, penalty=l1, solver=liblinear, score=0.870, total=  23.3s
# [CV] C=1000, max_iter=1000, penalty=l1, solver=liblinear .............
# [CV]  C=1000, max_iter=1000, penalty=l1, solver=liblinear, score=0.895, total=  14.7s
# [CV] C=1000, max_iter=1000, penalty=l1, solver=liblinear .............
# [CV]  C=1000, max_iter=1000, penalty=l1, solver=liblinear, score=0.886, total=  14.8s
# [CV] C=1000, max_iter=1000, penalty=l1, solver=lbfgs .................
# [CV]  C=1000, max_iter=1000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1000, max_iter=1000, penalty=l1, solver=lbfgs .................
# [CV]  C=1000, max_iter=1000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1000, max_iter=1000, penalty=l1, solver=lbfgs .................
# [CV]  C=1000, max_iter=1000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1000, max_iter=1000, penalty=l1, solver=lbfgs .................
# [CV]  C=1000, max_iter=1000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1000, max_iter=1000, penalty=l1, solver=lbfgs .................
# [CV]  C=1000, max_iter=1000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1000, max_iter=1000, penalty=l2, solver=liblinear .............
# /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1304, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 442, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV]  C=1000, max_iter=1000, penalty=l2, solver=liblinear, score=0.898, total=   0.3s
# [CV] C=1000, max_iter=1000, penalty=l2, solver=liblinear .............
# [CV]  C=1000, max_iter=1000, penalty=l2, solver=liblinear, score=0.881, total=   0.3s
# [CV] C=1000, max_iter=1000, penalty=l2, solver=liblinear .............
# [CV]  C=1000, max_iter=1000, penalty=l2, solver=liblinear, score=0.867, total=   0.3s
# [CV] C=1000, max_iter=1000, penalty=l2, solver=liblinear .............
# [CV]  C=1000, max_iter=1000, penalty=l2, solver=liblinear, score=0.892, total=   0.3s
# [CV] C=1000, max_iter=1000, penalty=l2, solver=liblinear .............
# [CV]  C=1000, max_iter=1000, penalty=l2, solver=liblinear, score=0.881, total=   0.3s
# [CV] C=1000, max_iter=1000, penalty=l2, solver=lbfgs .................
# /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV]  C=1000, max_iter=1000, penalty=l2, solver=lbfgs, score=0.899, total=   1.2s
# [CV] C=1000, max_iter=1000, penalty=l2, solver=lbfgs .................
# /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV]  C=1000, max_iter=1000, penalty=l2, solver=lbfgs, score=0.890, total=   1.3s
# [CV] C=1000, max_iter=1000, penalty=l2, solver=lbfgs .................
# /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV]  C=1000, max_iter=1000, penalty=l2, solver=lbfgs, score=0.872, total=   1.2s
# [CV] C=1000, max_iter=1000, penalty=l2, solver=lbfgs .................
# /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV]  C=1000, max_iter=1000, penalty=l2, solver=lbfgs, score=0.894, total=   1.2s
# [CV] C=1000, max_iter=1000, penalty=l2, solver=lbfgs .................
# /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV]  C=1000, max_iter=1000, penalty=l2, solver=lbfgs, score=0.888, total=   1.2s
# [CV] C=1000, max_iter=5000, penalty=l1, solver=liblinear .............
# [CV]  C=1000, max_iter=5000, penalty=l1, solver=liblinear, score=0.898, total=  17.4s
# [CV] C=1000, max_iter=5000, penalty=l1, solver=liblinear .............
# [CV]  C=1000, max_iter=5000, penalty=l1, solver=liblinear, score=0.876, total=  10.9s
# [CV] C=1000, max_iter=5000, penalty=l1, solver=liblinear .............
# [CV]  C=1000, max_iter=5000, penalty=l1, solver=liblinear, score=0.870, total=  26.0s
# [CV] C=1000, max_iter=5000, penalty=l1, solver=liblinear .............
# [CV]  C=1000, max_iter=5000, penalty=l1, solver=liblinear, score=0.895, total=  14.9s
# [CV] C=1000, max_iter=5000, penalty=l1, solver=liblinear .............
# [CV]  C=1000, max_iter=5000, penalty=l1, solver=liblinear, score=0.885, total=  15.6s
# [CV] C=1000, max_iter=5000, penalty=l1, solver=lbfgs .................
# [CV]  C=1000, max_iter=5000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1000, max_iter=5000, penalty=l1, solver=lbfgs .................
# [CV]  C=1000, max_iter=5000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1000, max_iter=5000, penalty=l1, solver=lbfgs .................
# [CV]  C=1000, max_iter=5000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1000, max_iter=5000, penalty=l1, solver=lbfgs .................
# [CV]  C=1000, max_iter=5000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1000, max_iter=5000, penalty=l1, solver=lbfgs .................
# [CV]  C=1000, max_iter=5000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1000, max_iter=5000, penalty=l2, solver=liblinear .............
# /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1304, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 442, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV]  C=1000, max_iter=5000, penalty=l2, solver=liblinear, score=0.898, total=   0.3s
# [CV] C=1000, max_iter=5000, penalty=l2, solver=liblinear .............
# [CV]  C=1000, max_iter=5000, penalty=l2, solver=liblinear, score=0.881, total=   0.3s
# [CV] C=1000, max_iter=5000, penalty=l2, solver=liblinear .............
# [CV]  C=1000, max_iter=5000, penalty=l2, solver=liblinear, score=0.867, total=   0.3s
# [CV] C=1000, max_iter=5000, penalty=l2, solver=liblinear .............
# [CV]  C=1000, max_iter=5000, penalty=l2, solver=liblinear, score=0.892, total=   0.3s
# [CV] C=1000, max_iter=5000, penalty=l2, solver=liblinear .............
# [CV]  C=1000, max_iter=5000, penalty=l2, solver=liblinear, score=0.881, total=   0.3s
# [CV] C=1000, max_iter=5000, penalty=l2, solver=lbfgs .................
# [CV]  C=1000, max_iter=5000, penalty=l2, solver=lbfgs, score=0.900, total=   2.4s
# [CV] C=1000, max_iter=5000, penalty=l2, solver=lbfgs .................
# [CV]  C=1000, max_iter=5000, penalty=l2, solver=lbfgs, score=0.889, total=   2.8s
# [CV] C=1000, max_iter=5000, penalty=l2, solver=lbfgs .................
# [CV]  C=1000, max_iter=5000, penalty=l2, solver=lbfgs, score=0.871, total=   2.6s
# [CV] C=1000, max_iter=5000, penalty=l2, solver=lbfgs .................
# [CV]  C=1000, max_iter=5000, penalty=l2, solver=lbfgs, score=0.896, total=   3.2s
# [CV] C=1000, max_iter=5000, penalty=l2, solver=lbfgs .................
# [CV]  C=1000, max_iter=5000, penalty=l2, solver=lbfgs, score=0.891, total=   4.8s
# [CV] C=1000, max_iter=10000, penalty=l1, solver=liblinear ............
# [CV]  C=1000, max_iter=10000, penalty=l1, solver=liblinear, score=0.897, total=  15.0s
# [CV] C=1000, max_iter=10000, penalty=l1, solver=liblinear ............
# [CV]  C=1000, max_iter=10000, penalty=l1, solver=liblinear, score=0.877, total=  10.6s
# [CV] C=1000, max_iter=10000, penalty=l1, solver=liblinear ............
# [CV]  C=1000, max_iter=10000, penalty=l1, solver=liblinear, score=0.870, total=  24.8s
# [CV] C=1000, max_iter=10000, penalty=l1, solver=liblinear ............
# [CV]  C=1000, max_iter=10000, penalty=l1, solver=liblinear, score=0.895, total=  13.8s
# [CV] C=1000, max_iter=10000, penalty=l1, solver=liblinear ............
# [CV]  C=1000, max_iter=10000, penalty=l1, solver=liblinear, score=0.885, total=  14.3s
# [CV] C=1000, max_iter=10000, penalty=l1, solver=lbfgs ................
# [CV]  C=1000, max_iter=10000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1000, max_iter=10000, penalty=l1, solver=lbfgs ................
# [CV]  C=1000, max_iter=10000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1000, max_iter=10000, penalty=l1, solver=lbfgs ................
# [CV]  C=1000, max_iter=10000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1000, max_iter=10000, penalty=l1, solver=lbfgs ................
# [CV]  C=1000, max_iter=10000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1000, max_iter=10000, penalty=l1, solver=lbfgs ................
# [CV]  C=1000, max_iter=10000, penalty=l1, solver=lbfgs, score=nan, total=   0.0s
# [CV] C=1000, max_iter=10000, penalty=l2, solver=liblinear ............
# /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1304, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 442, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV]  C=1000, max_iter=10000, penalty=l2, solver=liblinear, score=0.898, total=   0.3s
# [CV] C=1000, max_iter=10000, penalty=l2, solver=liblinear ............
# [CV]  C=1000, max_iter=10000, penalty=l2, solver=liblinear, score=0.881, total=   0.3s
# [CV] C=1000, max_iter=10000, penalty=l2, solver=liblinear ............
# [CV]  C=1000, max_iter=10000, penalty=l2, solver=liblinear, score=0.867, total=   0.3s
# [CV] C=1000, max_iter=10000, penalty=l2, solver=liblinear ............
# [CV]  C=1000, max_iter=10000, penalty=l2, solver=liblinear, score=0.892, total=   0.3s
# [CV] C=1000, max_iter=10000, penalty=l2, solver=liblinear ............
# [CV]  C=1000, max_iter=10000, penalty=l2, solver=liblinear, score=0.881, total=   0.3s
# [CV] C=1000, max_iter=10000, penalty=l2, solver=lbfgs ................
# [CV]  C=1000, max_iter=10000, penalty=l2, solver=lbfgs, score=0.900, total=   2.2s
# [CV] C=1000, max_iter=10000, penalty=l2, solver=lbfgs ................
# [CV]  C=1000, max_iter=10000, penalty=l2, solver=lbfgs, score=0.889, total=   2.7s
# [CV] C=1000, max_iter=10000, penalty=l2, solver=lbfgs ................
# [CV]  C=1000, max_iter=10000, penalty=l2, solver=lbfgs, score=0.871, total=   2.5s
# [CV] C=1000, max_iter=10000, penalty=l2, solver=lbfgs ................
# [CV]  C=1000, max_iter=10000, penalty=l2, solver=lbfgs, score=0.896, total=   3.0s
# [CV] C=1000, max_iter=10000, penalty=l2, solver=lbfgs ................
# [CV]  C=1000, max_iter=10000, penalty=l2, solver=lbfgs, score=0.891, total=   4.6s
# [Parallel(n_jobs=1)]: Done 540 out of 540 | elapsed: 10.6min finished
# GridSearchCV(estimator=LogisticRegression(),
#              param_grid={'C': [1e-05, 0.0001, 0.001, 0.01, 0.1, 1, 10, 100,
#                                1000],
#                          'max_iter': [1000, 5000, 10000],
#                          'penalty': ['l1', 'l2'],
#                          'solver': ['liblinear', 'lbfgs']},
#              verbose=3)

# %%
print(f"The best paramaters for the tuned model: {grid1.best_params_}\n") 
print(f"The cross-validated accuracy for the tuned model with normalized training set:{round(grid1.best_score_*100,2)}%")
# Out:
# The best paramaters for the tuned model: {'C': 1000, 'max_iter': 5000, 'penalty': 'l2', 'solver': 'lbfgs'}
#
# The cross-validated accuracy for the tuned model with normalized training set:88.96%

# %% [markdown]
# After model tuning, the cross-validated accuracy is increased from 84.51% to 88.19%.

# %% [markdown]
# Results on the whole training set

# %%
predictions1 = grid1.predict(X_train_scaled)
print(classification_report(y_train, predictions1))
print(f"{round(grid1.score(X_train_scaled, y_train)*100,2)}%")  # 88.44%, 89.3%
# Out:
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.84      0.72      0.77      1265
#      CONFIRMED       0.77      0.86      0.81      1350
# FALSE POSITIVE       0.98      1.00      0.99      2628
#
#       accuracy                           0.89      5243
#      macro avg       0.86      0.86      0.86      5243
#   weighted avg       0.89      0.89      0.89      5243
#
# 89.3%

# %% [markdown]
# ### 2. Standardized data

# %%
grid2 = GridSearchCV(model, param_grid2, verbose = 3, n_jobs = -1)
grid2.fit(X_train_stand, y_train)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 135 out of 135 | elapsed:   22.4s finished
# /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# GridSearchCV(estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': [1e-05, 0.0001, 0.001, 0.01, 0.1, 1, 10, 100,
#                                1000],
#                          'max_iter': [1000, 5000, 10000]},
#              verbose=3)

# %%
print(f"The best paramaters for the tuned model: {grid2.best_params_}\n")
print(f"The cross-validated accuracy for the tuned model with standardized training set:{round(grid2.best_score_*100,2)}%")
# Out:
# The best paramaters for the tuned model: {'C': 1000, 'max_iter': 1000}
#
# The cross-validated accuracy for the tuned model with standardized training set:89.01%

# %% [markdown]
# After model tuning, the cross-validated accuracy is increased from 88.86% to 89.01%.

# %% [markdown]
# Results on the whole training set

# %%
predictions2 = grid2.predict(X_train_stand)
print(classification_report(y_train, predictions2))
print(f"{round(grid2.score(X_train_stand, y_train)*100,2)}%") #89.3% 89.36%
# Out:
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.84      0.72      0.77      1265
#      CONFIRMED       0.77      0.86      0.81      1350
# FALSE POSITIVE       0.99      1.00      0.99      2628
#
#       accuracy                           0.89      5243
#      macro avg       0.86      0.86      0.86      5243
#   weighted avg       0.89      0.89      0.89      5243
#
# 89.36%

# %% [markdown]
# The tuned model with standardized data perfoems slightly better than the tuned model with normalized data, as the cross-validated accuracy of the tuned model with standardized data (89.01%) is higher than the one with normalized data (88.19%).
#
# The final logistic regression model :
# 1. Requires the standardization of data.
# 2. Model parameters:  {'C': 10, 'penalty': 'l2', 'solver': 'lbfgs'}
# 3. Cross-validated accuracy: 89.01%

# %% [markdown]
# # Save the tuned model

# %%
import joblib
filename = 'logistic_regression.sav'
joblib.dump(grid2, filename)
# Out:
# ['logistic_regression.sav']
