# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Requirement already satisfied, skipping upgrade: scikit-learn in /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages (from sklearn) (0.23.1)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.5.0)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (0.16.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.18.5)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1315 sha256=b9cefa613fd16ab9a301d7fd3819642d85981c9a267dafa93f5335100541ddc8
#   Stored in directory: /Users/jiaping/Library/Caches/pip/wheels/22/0b/40/fd3f795caaa1fb4c6cb738bc1f56100be1e57da95849bfc897
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in /Users/jiaping/opt/anaconda3/lib/python3.8/site-packages (0.16.0)

# %%
import pandas as pd
import tensorflow

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("../Resources/exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select X, y values

# %%
# Set features. This will also be used as your x values.
X = df.drop('koi_disposition',axis=1)
features = X.columns
y = df['koi_disposition']

# %% [markdown]
# # Data Pre-Processing

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Label-encode the data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
X_train.shape
# Out:
# (5243, 40)

# %%
y_train_categorical.shape
# Out:
# (5243, 3)

# %% [markdown]
# # Create a deep learning model

# %%
from tensorflow.keras.models import Sequential
model = Sequential()

from tensorflow.keras.layers import Dense
number_inputs = 40
number_hidden_nodes = 6
number_classes = 3
model.add(Dense(units=number_hidden_nodes,
               activation='relu',input_dim=number_inputs))
model.add(Dense(units=number_hidden_nodes,
                activation='relu'))
model.add(Dense(units=number_classes,
               activation='softmax'))

# %%
# compile and fit the model
model.compile(loss="categorical_crossentropy",
              optimizer="adam", metrics=['accuracy'])

model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 164/164 - 0s - loss: 1.0141 - accuracy: 0.4946
# Epoch 2/100
# 164/164 - 0s - loss: 0.8576 - accuracy: 0.4972
# Epoch 3/100
# 164/164 - 0s - loss: 0.7058 - accuracy: 0.6634
# Epoch 4/100
# 164/164 - 0s - loss: 0.6037 - accuracy: 0.7353
# Epoch 5/100
# 164/164 - 0s - loss: 0.5440 - accuracy: 0.7446
# Epoch 6/100
# 164/164 - 0s - loss: 0.5079 - accuracy: 0.7463
# Epoch 7/100
# 164/164 - 0s - loss: 0.4856 - accuracy: 0.7467
# Epoch 8/100
# 164/164 - 0s - loss: 0.4699 - accuracy: 0.7467
# Epoch 9/100
# 164/164 - 0s - loss: 0.4588 - accuracy: 0.7469
# Epoch 10/100
# 164/164 - 0s - loss: 0.4497 - accuracy: 0.7471
# Epoch 11/100
# 164/164 - 0s - loss: 0.4426 - accuracy: 0.7471
# Epoch 12/100
# 164/164 - 0s - loss: 0.4374 - accuracy: 0.7471
# Epoch 13/100
# 164/164 - 0s - loss: 0.4326 - accuracy: 0.7471
# Epoch 14/100
# 164/164 - 0s - loss: 0.4280 - accuracy: 0.7473
# Epoch 15/100
# 164/164 - 0s - loss: 0.4247 - accuracy: 0.7473
# Epoch 16/100
# 164/164 - 0s - loss: 0.4223 - accuracy: 0.7471
# Epoch 17/100
# 164/164 - 0s - loss: 0.4198 - accuracy: 0.7473
# Epoch 18/100
# 164/164 - 0s - loss: 0.4175 - accuracy: 0.7473
# Epoch 19/100
# 164/164 - 0s - loss: 0.4156 - accuracy: 0.7473
# Epoch 20/100
# 164/164 - 0s - loss: 0.4140 - accuracy: 0.7473
# Epoch 21/100
# 164/164 - 0s - loss: 0.4125 - accuracy: 0.7473
# Epoch 22/100
# 164/164 - 0s - loss: 0.4112 - accuracy: 0.7473
# Epoch 23/100
# 164/164 - 0s - loss: 0.4099 - accuracy: 0.7473
# Epoch 24/100
# 164/164 - 0s - loss: 0.4098 - accuracy: 0.7475
# Epoch 25/100
# 164/164 - 0s - loss: 0.4082 - accuracy: 0.7475
# Epoch 26/100
# 164/164 - 0s - loss: 0.4072 - accuracy: 0.7473
# Epoch 27/100
# 164/164 - 0s - loss: 0.4061 - accuracy: 0.7473
# Epoch 28/100
# 164/164 - 0s - loss: 0.4059 - accuracy: 0.7473
# Epoch 29/100
# 164/164 - 0s - loss: 0.4051 - accuracy: 0.7475
# Epoch 30/100
# 164/164 - 0s - loss: 0.4041 - accuracy: 0.7473
# Epoch 31/100
# 164/164 - 0s - loss: 0.4033 - accuracy: 0.7473
# Epoch 32/100
# 164/164 - 0s - loss: 0.4042 - accuracy: 0.7473
# Epoch 33/100
# 164/164 - 0s - loss: 0.4025 - accuracy: 0.7473
# Epoch 34/100
# 164/164 - 0s - loss: 0.4022 - accuracy: 0.7473
# Epoch 35/100
# 164/164 - 0s - loss: 0.4016 - accuracy: 0.7475
# Epoch 36/100
# 164/164 - 0s - loss: 0.4023 - accuracy: 0.7473
# Epoch 37/100
# 164/164 - 0s - loss: 0.4012 - accuracy: 0.7473
# Epoch 38/100
# 164/164 - 0s - loss: 0.4011 - accuracy: 0.7473
# Epoch 39/100
# 164/164 - 0s - loss: 0.4006 - accuracy: 0.7473
# Epoch 40/100
# 164/164 - 0s - loss: 0.4011 - accuracy: 0.7473
# Epoch 41/100
# 164/164 - 0s - loss: 0.4003 - accuracy: 0.7473
# Epoch 42/100
# 164/164 - 0s - loss: 0.3998 - accuracy: 0.7473
# Epoch 43/100
# 164/164 - 0s - loss: 0.3995 - accuracy: 0.7473
# Epoch 44/100
# 164/164 - 0s - loss: 0.3995 - accuracy: 0.7473
# Epoch 45/100
# 164/164 - 0s - loss: 0.3996 - accuracy: 0.7473
# Epoch 46/100
# 164/164 - 0s - loss: 0.3992 - accuracy: 0.7473
# Epoch 47/100
# 164/164 - 0s - loss: 0.3986 - accuracy: 0.7473
# Epoch 48/100
# 164/164 - 0s - loss: 0.3987 - accuracy: 0.7473
# Epoch 49/100
# 164/164 - 0s - loss: 0.3987 - accuracy: 0.7473
# Epoch 50/100
# 164/164 - 0s - loss: 0.3984 - accuracy: 0.7486
# Epoch 51/100
# 164/164 - 0s - loss: 0.3987 - accuracy: 0.7473
# Epoch 52/100
# 164/164 - 0s - loss: 0.3980 - accuracy: 0.7475
# Epoch 53/100
# 164/164 - 0s - loss: 0.3979 - accuracy: 0.7473
# Epoch 54/100
# 164/164 - 0s - loss: 0.3979 - accuracy: 0.7473
# Epoch 55/100
# 164/164 - 0s - loss: 0.3981 - accuracy: 0.7477
# Epoch 56/100
# 164/164 - 0s - loss: 0.3978 - accuracy: 0.7479
# Epoch 57/100
# 164/164 - 0s - loss: 0.3976 - accuracy: 0.7477
# Epoch 58/100
# 164/164 - 0s - loss: 0.3980 - accuracy: 0.7477
# Epoch 59/100
# 164/164 - 0s - loss: 0.3977 - accuracy: 0.7500
# Epoch 60/100
# 164/164 - 0s - loss: 0.3982 - accuracy: 0.7501
# Epoch 61/100
# 164/164 - 0s - loss: 0.3976 - accuracy: 0.7480
# Epoch 62/100
# 164/164 - 0s - loss: 0.3971 - accuracy: 0.7530
# Epoch 63/100
# 164/164 - 0s - loss: 0.3967 - accuracy: 0.7511
# Epoch 64/100
# 164/164 - 0s - loss: 0.3966 - accuracy: 0.7566
# Epoch 65/100
# 164/164 - 0s - loss: 0.3967 - accuracy: 0.7530
# Epoch 66/100
# 164/164 - 0s - loss: 0.3966 - accuracy: 0.7559
# Epoch 67/100
# 164/164 - 0s - loss: 0.3965 - accuracy: 0.7561
# Epoch 68/100
# 164/164 - 0s - loss: 0.3968 - accuracy: 0.7576
# Epoch 69/100
# 164/164 - 0s - loss: 0.3962 - accuracy: 0.7591
# Epoch 70/100
# 164/164 - 0s - loss: 0.3967 - accuracy: 0.7591
# Epoch 71/100
# 164/164 - 0s - loss: 0.3966 - accuracy: 0.7616
# Epoch 72/100
# 164/164 - 0s - loss: 0.3964 - accuracy: 0.7614
# Epoch 73/100
# 164/164 - 0s - loss: 0.3956 - accuracy: 0.7622
# Epoch 74/100
# 164/164 - 0s - loss: 0.3970 - accuracy: 0.7673
# Epoch 75/100
# 164/164 - 0s - loss: 0.3951 - accuracy: 0.7723
# Epoch 76/100
# 164/164 - 0s - loss: 0.3939 - accuracy: 0.7784
# Epoch 77/100
# 164/164 - 0s - loss: 0.3932 - accuracy: 0.7894
# Epoch 78/100
# 164/164 - 0s - loss: 0.3910 - accuracy: 0.8055
# Epoch 79/100
# 164/164 - 0s - loss: 0.3884 - accuracy: 0.8116
# Epoch 80/100
# 164/164 - 0s - loss: 0.3860 - accuracy: 0.8159
# Epoch 81/100
# 164/164 - 0s - loss: 0.3843 - accuracy: 0.8158
# Epoch 82/100
# 164/164 - 0s - loss: 0.3828 - accuracy: 0.8171
# Epoch 83/100
# 164/164 - 0s - loss: 0.3818 - accuracy: 0.8201
# Epoch 84/100
# 164/164 - 0s - loss: 0.3803 - accuracy: 0.8184
# Epoch 85/100
# 164/164 - 0s - loss: 0.3793 - accuracy: 0.8203
# Epoch 86/100
# 164/164 - 0s - loss: 0.3778 - accuracy: 0.8213
# Epoch 87/100
# 164/164 - 0s - loss: 0.3774 - accuracy: 0.8207
# Epoch 88/100
# 164/164 - 0s - loss: 0.3761 - accuracy: 0.8226
# Epoch 89/100
# 164/164 - 0s - loss: 0.3746 - accuracy: 0.8217
# Epoch 90/100
# 164/164 - 0s - loss: 0.3738 - accuracy: 0.8257
# Epoch 91/100
# 164/164 - 0s - loss: 0.3733 - accuracy: 0.8262
# Epoch 92/100
# 164/164 - 0s - loss: 0.3721 - accuracy: 0.8220
# Epoch 93/100
# 164/164 - 0s - loss: 0.3714 - accuracy: 0.8205
# Epoch 94/100
# 164/164 - 0s - loss: 0.3698 - accuracy: 0.8247
# Epoch 95/100
# 164/164 - 0s - loss: 0.3703 - accuracy: 0.8255
# Epoch 96/100
# 164/164 - 0s - loss: 0.3691 - accuracy: 0.8245
# Epoch 97/100
# 164/164 - 0s - loss: 0.3675 - accuracy: 0.8230
# Epoch 98/100
# 164/164 - 0s - loss: 0.3680 - accuracy: 0.8236
# Epoch 99/100
# 164/164 - 0s - loss: 0.3662 - accuracy: 0.8274
# Epoch 100/100
# 164/164 - 0s - loss: 0.3658 - accuracy: 0.8243

# %% [markdown]
# ## Quantify our Trained Model

# %%
model_loss, model_accuracy = model.evaluate(X_test_scaled, y_test_categorical, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.3329 - accuracy: 0.8507
# Loss: 0.3329112231731415, Accuracy: 0.8506864905357361

# %% [markdown]
# ## Make Predictions

# %%
# Use the first 20 test data values to make a prediction and compare it to the actual labels
print(f"Actual Labels: {list(y_test[:20])}")
# Out:
# Actual Labels: ['CONFIRMED', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CONFIRMED', 'FALSE POSITIVE', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CONFIRMED', 'CANDIDATE', 'FALSE POSITIVE', 'CONFIRMED', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CANDIDATE', 'CANDIDATE', 'CONFIRMED', 'FALSE POSITIVE', 'FALSE POSITIVE', 'CONFIRMED', 'CANDIDATE']

# %%
predictions = model.predict_classes(X_test_scaled[:20])
print(predictions)
# Out:
# [0 2 2 1 2 2 2 1 1 2 1 2 2 1 0 1 2 2 1 0]

# %%
pred_classes = label_encoder.inverse_transform(predictions)
print(pred_classes)
# Out:
# ['CANDIDATE' 'FALSE POSITIVE' 'FALSE POSITIVE' 'CONFIRMED'
#  'FALSE POSITIVE' 'FALSE POSITIVE' 'FALSE POSITIVE' 'CONFIRMED'
#  'CONFIRMED' 'FALSE POSITIVE' 'CONFIRMED' 'FALSE POSITIVE'
#  'FALSE POSITIVE' 'CONFIRMED' 'CANDIDATE' 'CONFIRMED' 'FALSE POSITIVE'
#  'FALSE POSITIVE' 'CONFIRMED' 'CANDIDATE']

# %%
pd.DataFrame({"Actual": y_test[:20], "Predicted":pred_classes})
# Out:
#               Actual       Predicted
# 1213       CONFIRMED       CANDIDATE
# 5220  FALSE POSITIVE  FALSE POSITIVE
# 6688  FALSE POSITIVE  FALSE POSITIVE
# 2031       CONFIRMED       CONFIRMED
# 5824  FALSE POSITIVE  FALSE POSITIVE
# 2053  FALSE POSITIVE  FALSE POSITIVE
# 2567  FALSE POSITIVE  FALSE POSITIVE
# 1687       CONFIRMED       CONFIRMED
# 1837       CANDIDATE       CONFIRMED
# 4016  FALSE POSITIVE  FALSE POSITIVE
# 901        CONFIRMED       CONFIRMED
# 691   FALSE POSITIVE  FALSE POSITIVE
# 724   FALSE POSITIVE  FALSE POSITIVE
# 5011       CANDIDATE       CONFIRMED
# 2912       CANDIDATE       CANDIDATE
# 2641       CONFIRMED       CONFIRMED
# 6588  FALSE POSITIVE  FALSE POSITIVE
# 5705  FALSE POSITIVE  FALSE POSITIVE
# 1657       CONFIRMED       CONFIRMED
# 3004       CANDIDATE       CANDIDATE

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS

import joblib
filename2 = 'deep_learning.sav'
joblib.dump(model, filename2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-015cd2ce3e02> in <module>
#       5 import joblib
#       6 filename2 = 'deep_learning.sav'
# ----> 7 joblib.dump(model, filename2)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/numpy_pickle.py in dump(value, filename, compress, protocol, cache_size)
#     478     elif is_filename:
#     479         with open(filename, 'wb') as f:
# --> 480             NumpyPickler(f, protocol=protocol).dump(value)
#     481     else:
#     482         NumpyPickler(filename, protocol=protocol).dump(value)
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in dump(self, obj)
#     483         if self.proto >= 4:
#     484             self.framer.start_framing()
# --> 485         self.save(obj)
#     486         self.write(STOP)
#     487         self.framer.end_framing()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     599
#     600         # Save the reduce() output and finally memoize the object
# --> 601         self.save_reduce(obj=obj, *rv)
#     602
#     603     def persistent_id(self, obj):
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     713         if state is not None:
#     714             if state_setter is None:
# --> 715                 save(state)
#     716                 write(BUILD)
#     717             else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     556             f = self.dispatch.get(t)
#     557             if f is not None:
# --> 558                 f(self, obj)  # Call unbound method with explicit self
#     559                 return
#     560
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in save_dict(self, obj)
#     967
#     968         self.memoize(obj)
# --> 969         self._batch_setitems(obj.items())
#     970
#     971     dispatch[dict] = save_dict
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in _batch_setitems(self, items)
#     993                 for k, v in tmp:
#     994                     save(k)
# --> 995                     save(v)
#     996                 write(SETITEMS)
#     997             elif n:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     556             f = self.dispatch.get(t)
#     557             if f is not None:
# --> 558                 f(self, obj)  # Call unbound method with explicit self
#     559                 return
#     560
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in save_list(self, obj)
#     927
#     928         self.memoize(obj)
# --> 929         self._batch_appends(obj)
#     930
#     931     dispatch[list] = save_list
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in _batch_appends(self, items)
#     951                 write(MARK)
#     952                 for x in tmp:
# --> 953                     save(x)
#     954                 write(APPENDS)
#     955             elif n:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     599
#     600         # Save the reduce() output and finally memoize the object
# --> 601         self.save_reduce(obj=obj, *rv)
#     602
#     603     def persistent_id(self, obj):
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     713         if state is not None:
#     714             if state_setter is None:
# --> 715                 save(state)
#     716                 write(BUILD)
#     717             else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     556             f = self.dispatch.get(t)
#     557             if f is not None:
# --> 558                 f(self, obj)  # Call unbound method with explicit self
#     559                 return
#     560
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in save_dict(self, obj)
#     967
#     968         self.memoize(obj)
# --> 969         self._batch_setitems(obj.items())
#     970
#     971     dispatch[dict] = save_dict
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in _batch_setitems(self, items)
#     993                 for k, v in tmp:
#     994                     save(k)
# --> 995                     save(v)
#     996                 write(SETITEMS)
#     997             elif n:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     556             f = self.dispatch.get(t)
#     557             if f is not None:
# --> 558                 f(self, obj)  # Call unbound method with explicit self
#     559                 return
#     560
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in save_list(self, obj)
#     927
#     928         self.memoize(obj)
# --> 929         self._batch_appends(obj)
#     930
#     931     dispatch[list] = save_list
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in _batch_appends(self, items)
#     954                 write(APPENDS)
#     955             elif n:
# --> 956                 save(tmp[0])
#     957                 write(APPEND)
#     958             # else tmp is empty, and we're done
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     599
#     600         # Save the reduce() output and finally memoize the object
# --> 601         self.save_reduce(obj=obj, *rv)
#     602
#     603     def persistent_id(self, obj):
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     713         if state is not None:
#     714             if state_setter is None:
# --> 715                 save(state)
#     716                 write(BUILD)
#     717             else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     556             f = self.dispatch.get(t)
#     557             if f is not None:
# --> 558                 f(self, obj)  # Call unbound method with explicit self
#     559                 return
#     560
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in save_dict(self, obj)
#     967
#     968         self.memoize(obj)
# --> 969         self._batch_setitems(obj.items())
#     970
#     971     dispatch[dict] = save_dict
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in _batch_setitems(self, items)
#     993                 for k, v in tmp:
#     994                     save(k)
# --> 995                     save(v)
#     996                 write(SETITEMS)
#     997             elif n:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     599
#     600         # Save the reduce() output and finally memoize the object
# --> 601         self.save_reduce(obj=obj, *rv)
#     602
#     603     def persistent_id(self, obj):
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     713         if state is not None:
#     714             if state_setter is None:
# --> 715                 save(state)
#     716                 write(BUILD)
#     717             else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     556             f = self.dispatch.get(t)
#     557             if f is not None:
# --> 558                 f(self, obj)  # Call unbound method with explicit self
#     559                 return
#     560
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in save_dict(self, obj)
#     967
#     968         self.memoize(obj)
# --> 969         self._batch_setitems(obj.items())
#     970
#     971     dispatch[dict] = save_dict
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in _batch_setitems(self, items)
#     993                 for k, v in tmp:
#     994                     save(k)
# --> 995                     save(v)
#     996                 write(SETITEMS)
#     997             elif n:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     599
#     600         # Save the reduce() output and finally memoize the object
# --> 601         self.save_reduce(obj=obj, *rv)
#     602
#     603     def persistent_id(self, obj):
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     713         if state is not None:
#     714             if state_setter is None:
# --> 715                 save(state)
#     716                 write(BUILD)
#     717             else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     556             f = self.dispatch.get(t)
#     557             if f is not None:
# --> 558                 f(self, obj)  # Call unbound method with explicit self
#     559                 return
#     560
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in save_dict(self, obj)
#     967
#     968         self.memoize(obj)
# --> 969         self._batch_setitems(obj.items())
#     970
#     971     dispatch[dict] = save_dict
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in _batch_setitems(self, items)
#     993                 for k, v in tmp:
#     994                     save(k)
# --> 995                     save(v)
#     996                 write(SETITEMS)
#     997             elif n:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     599
#     600         # Save the reduce() output and finally memoize the object
# --> 601         self.save_reduce(obj=obj, *rv)
#     602
#     603     def persistent_id(self, obj):
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     713         if state is not None:
#     714             if state_setter is None:
# --> 715                 save(state)
#     716                 write(BUILD)
#     717             else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     556             f = self.dispatch.get(t)
#     557             if f is not None:
# --> 558                 f(self, obj)  # Call unbound method with explicit self
#     559                 return
#     560
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in save_dict(self, obj)
#     967
#     968         self.memoize(obj)
# --> 969         self._batch_setitems(obj.items())
#     970
#     971     dispatch[dict] = save_dict
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in _batch_setitems(self, items)
#     993                 for k, v in tmp:
#     994                     save(k)
# --> 995                     save(v)
#     996                 write(SETITEMS)
#     997             elif n:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     280             return
#     281
# --> 282         return Pickler.save(self, obj)
#     283
#     284
#
# ~/opt/anaconda3/lib/python3.8/pickle.py in save(self, obj, save_persistent_id)
#     574                 reduce = getattr(obj, "__reduce_ex__", None)
#     575                 if reduce is not None:
# --> 576                     rv = reduce(self.proto)
#     577                 else:
#     578                     reduce = getattr(obj, "__reduce__", None)
#
# TypeError: cannot pickle '_thread.RLock' object
