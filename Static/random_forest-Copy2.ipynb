# %%
from sklearn import tree
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../Resources/cleaned_data.csv")
df
# Out:
#      koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0          CONFIRMED              0              0              0
# 1     FALSE POSITIVE              0              1              0
# 2     FALSE POSITIVE              0              1              0
# 3          CONFIRMED              0              0              0
# 4          CONFIRMED              0              0              0
# ...              ...            ...            ...            ...
# 6986  FALSE POSITIVE              0              0              0
# 6987  FALSE POSITIVE              0              1              1
# 6988       CANDIDATE              0              0              0
# 6989  FALSE POSITIVE              0              0              1
# 6990  FALSE POSITIVE              0              0              1
#
#       koi_fpflag_ec  koi_period  koi_period_err1  koi_period_err2  \
# 0                 0   54.418383     2.479000e-04    -2.479000e-04
# ...

# %%
y = df['koi_disposition']
target_names = ["CONFIRMED", "FALSE POSITIVE", "CANDIDATE"]
X = df.drop(columns='koi_disposition')
feature_names = X.columns
X.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
#
#    koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %% [markdown]
# The performance of decision tree model

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.8592677345537757

# %% [markdown]
# # Pre-processing
#
# Training/test set splitting and one-hot-encoding

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn import metrics
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify = y)
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %% [markdown]
# The performance of random forest model with default setting on training set

# %%
rf0 = RandomForestClassifier(oob_score=True, random_state=10)
rf0.fit(X_train,encoded_y_train)
print(rf0.oob_score_)
y_predprob = rf0.predict_proba(X_train) # the probabilities of each class
print(f"AUC Score (Train):{metrics.roc_auc_score(encoded_y_train, rf0.predict_proba(X_train), multi_class='ovr')}")
# Out:
# 0.8928094602326913
# AUC Score (Train):1.0

# %% [markdown]
# # Model Tuning
# First, optimize the model by tuning the number of estimators (number of trees in forest)

# %%
param_test1 = {'n_estimators':range(10,201,10)}
gsearch1 = GridSearchCV(estimator = RandomForestClassifier(min_samples_split=100,
                                  min_samples_leaf=20, max_depth=8,max_features='sqrt',random_state=10), 
                       param_grid = param_test1, scoring='roc_auc',cv=5)

gsearch1.fit(X_train, y_train_categorical)
gsearch1.cv_results_['mean_test_score'], gsearch1.best_params_, gsearch1.best_score_
# Out:
# (array([0.94834299, 0.95574062, 0.95726427, 0.95810021, 0.95861513,
#         0.95852297, 0.95884636, 0.95902091, 0.95889067, 0.95873874,
#         0.95909634, 0.95946837, 0.9593618 , 0.95947955, 0.95960087,
#         0.95943025, 0.95948002, 0.95974088, 0.95987783, 0.95981441]),
#  {'n_estimators': 190},
#  0.959877825281691)

# %% [markdown]
# According to the optimization results, the best hyperparameter for estimator is 190. The resulted cross-validated AUC is 95.99%.
#
# Then, optimze the model by tuning the max_depth

# %%
param_test2 = {'max_depth':range(3,14,2), 'min_samples_split':range(50,201,20)}
gsearch2 = GridSearchCV(estimator = RandomForestClassifier(n_estimators = 190,
                                  min_samples_leaf=20,max_features='sqrt',random_state=10), 
                       param_grid = param_test2, scoring='roc_auc',iid=False,cv=5)

gsearch2.fit(X_train, y_train_categorical)
gsearch2.cv_results_['mean_test_score'], gsearch2.best_params_, gsearch2.best_score_
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-e6e8cf41ec28> in <module>
#       4                        param_grid = param_test2, scoring='roc_auc',iid=False,cv=5)
#       5
# ----> 6 gsearch2.fit(X_train, y_train_categorical)
#       7 gsearch2.cv_results_['mean_test_score'], gsearch2.best_params_, gsearch2.best_score_
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# ...

# %%
rf1 = RandomForestClassifier(n_estimators= 60, max_depth=13, min_samples_split=110,
                                  min_samples_leaf=20,max_features='sqrt' ,oob_score=True, random_state=10)
rf1.fit(X,y)
print rf1.oob_score_

# %%
param_test3 = {'min_samples_split':range(80,150,20), 'min_samples_leaf':range(10,60,10)}
gsearch3 = GridSearchCV(estimator = RandomForestClassifier(n_estimators= 60, max_depth=13,
                                  max_features='sqrt' ,oob_score=True, random_state=10),
   param_grid = param_test3, scoring='roc_auc',iid=False, cv=5)
gsearch3.fit(X_train, y_train_categorical)
gsearch3.grid_scores_, gsearch3.best_params_, gsearch3.best_score_

# %%
param_test4 = {'max_features':range(3,11,2)}
gsearch4 = GridSearchCV(estimator = RandomForestClassifier(n_estimators= 60, max_depth=13, min_samples_split=120,
                                  min_samples_leaf=20 ,oob_score=True, random_state=10),
   param_grid = param_test4, scoring='roc_auc',iid=False, cv=5)

gsearch4.fit(X_train, y_train_categorical)
gsearch4.grid_scores_, gsearch4.best_params_, gsearch4.best_score_

# %%
rf2 = RandomForestClassifier(n_estimators= 60, max_depth=13, min_samples_split=120,
                                  min_samples_leaf=20,max_features=7 ,oob_score=True, random_state=10)
rf2.fit(X,y)
print rf2.oob_score_

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.11133271975468742, 'koi_fpflag_co'),
#  (0.09449208195590787, 'koi_fpflag_nt'),
#  (0.07333934602403787, 'koi_fpflag_ss'),
#  (0.056327167343656614, 'koi_model_snr'),
#  (0.05099226881431779, 'koi_prad'),
#  (0.03418475299321093, 'koi_prad_err2'),
#  (0.033829653797619916, 'koi_fpflag_ec'),
#  (0.033551325543753376, 'koi_duration_err1'),
#  (0.03232723774740154, 'koi_duration_err2'),
#  (0.030253088269462332, 'koi_steff_err2'),
#  (0.028929890967020776, 'koi_prad_err1'),
#  (0.02470861513226234, 'koi_steff_err1'),
#  (0.023288986850252064, 'koi_duration'),
#  (0.02259092281263069, 'koi_period'),
#  (0.02124480159914948, 'koi_time0bk_err2'),
#  (0.021225712906921528, 'koi_insol_err1'),
#  (0.02099995883607792, 'koi_time0bk_err1'),
#  (0.01969685175932427, 'koi_depth'),
#  (0.018381226311847514, 'koi_period_err2'),
#  (0.017414292655411383, 'koi_period_err1'),
#  (0.017080786950508572, 'koi_impact'),
#  (0.016096248777969238, 'koi_insol_err2'),
# ...

# %%
import joblib
filename = "random_forest.sav"
joblib.dump(rf, filename)
# Out:
# ['random_forest.sav']

# %%
predictions = rf.predict(X_test)
predictions_df = pd.DataFrame({"Actual": y_test, "Predicted":predictions})
predictions_df.head(20)
# Out:
#               Actual       Predicted
# 1213       CONFIRMED       CONFIRMED
# 5220  FALSE POSITIVE  FALSE POSITIVE
# 6688  FALSE POSITIVE  FALSE POSITIVE
# 2031       CONFIRMED       CONFIRMED
# 5824  FALSE POSITIVE  FALSE POSITIVE
# 2053  FALSE POSITIVE  FALSE POSITIVE
# 2567  FALSE POSITIVE  FALSE POSITIVE
# 1687       CONFIRMED       CONFIRMED
# 1837       CANDIDATE       CANDIDATE
# 4016  FALSE POSITIVE  FALSE POSITIVE
# 901        CONFIRMED       CONFIRMED
# 691   FALSE POSITIVE  FALSE POSITIVE
# 724   FALSE POSITIVE  FALSE POSITIVE
# 5011       CANDIDATE       CANDIDATE
# 2912       CANDIDATE       CANDIDATE
# 2641       CONFIRMED       CONFIRMED
# 6588  FALSE POSITIVE  FALSE POSITIVE
# 5705  FALSE POSITIVE  FALSE POSITIVE
# 1657       CONFIRMED       CONFIRMED
# 3004       CANDIDATE       CANDIDATE

# %%
predictions_df['match'] = np.where(predictions_df['Predicted'] == predictions_df['Actual'], 1, 0)
print(f"The number of total predictions: {len(predictions_df)}")
print(f"The number of correct predictions: {sum(predictions_df['match'])}")
print(f"The test test accuracy: {round(sum(predictions_df['match'])/len(predictions_df)*100,2)}%")
predictions_df[predictions_df['match']==0].index
# Out:
# The number of total predictions: 1748
# The number of correct predictions: 1599
# The test test accuracy: 91.48%
# Int64Index([5248, 2080,  161,  906, 2246,  119, 1862, 2624, 1316, 2019,
#             ...
#             2326, 2270,  795, 1288, 1685, 1228,  289, 2271, 2539,  958],
#            dtype='int64', length=149)
